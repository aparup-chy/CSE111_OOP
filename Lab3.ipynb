# %% [markdown]
# Lab 3 Tasks: https://drive.google.com/file/d/1sL9YaJRyvfXyoQx7CSPayOE0nlqbH-eq/view

# %%
#Task_1

class Calculator:
    def __init__(self,firstvalue=None,operator=None,secondvalue=None):
        print("Let's Calculate!")
        self.firstvalue=int(input("Value 1: "))
        self.operator=input("Operator: ")
        self.secondvalue=int(input("Value 2: "))
    
    def add(self):
        return(self.firstvalue+self.secondvalue)
    def substract(self):
        return(self.firstvalue-self.secondvalue)
    def multiply(self):
        return(self.firstvalue*self.secondvalue)
    def division(self):
        return(self.firstvalue/self.secondvalue)
    
obj=Calculator()
if obj.operator=="+":
    plus=obj.add()
    print("Result:",plus)
elif obj.operator=="-":
    minus=obj.substract()
    print("Result:",minus)
elif obj.operator=="*":
    into=obj.multiply()
    print("Result:",into)
elif obj.operator=="/":
    by=obj.division()
    print("Result:",by)
# Out:
# Let's Calculate!
# Value 1: 2
# Operator: +
# Value 2: 3
# Result: 5

# %%
#Task_2

class Course:
    def __init__(self,code,faculty,sec):
        self.code=code
        self.faculty=faculty
        self.sec=sec
    def detail(self):
        print(self.code,"-",self.faculty,"-",self.sec)

c1 = Course("CSE110", "TBA", 8)
c1.detail()
print("===============")
c2 = Course("CSE111", "TBA", 9)
c2.detail()
# Out:
# CSE110 - TBA - 8
# ===============
# CSE111 - TBA - 9

# %%
#Task_3

class Patient:
    def __init__(self,name,age,weight,height):
        self.name=name
        self.age=age
        self.weight=weight
        self.height=height

    def printDetails(self):
        print("Name:",self.name)
        print("Age:",self.age)
        print("Weight:",self.weight)
        print("Height",self.height)
        bmi = self.weight/(self.height/100)**2
        print("BMI:",bmi)

p1 = Patient("A", 55, 63.0, 158.0)
p1.printDetails()
print("====================")
p2 = Patient("B", 53, 61.0, 149.0)
p2.printDetails()
# Out:
# Name: A
# Age: 55
# Weight: 63.0
# Height 158.0
# BMI: 25.236340330075304
# ====================
# Name: B
# Age: 53
# Weight: 61.0
# Height 149.0
# BMI: 27.476239809017613

# %%
#Task_4

class Vehicle:
    def __init__(self):
        self.x=0
        self.y=0
    def print_position(self):
        print(f"({self.x},{self.y})")
    def moveUp(self):
        self.y+=1
    def moveLeft(self):
        self.x-=1
    def moveDown(self):
        self.y-=1
    def moveRight(self):
        self.x+=1

car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0,0)
# (0,1)
# (-1,1)
# (-1,0)

# %%
#Task_5

class Shape:
    def __init__(self,shape,x,y):
        self.shape=shape
        self.x=x
        self.y=y
    def area(self):
        if self.shape=="Triangle" or self.shape=="Rhombus":
            print(f"Area: {0.5*self.x*self.y}")
        elif self.shape=="Rectangle" or self.shape=="Square":
            print(f"Area: {self.x*self.y}")
        else:
            print("Area: Shape unknown")

triangle = Shape("Triangle",10,25)
triangle.area()
print("==========================")
square = Shape("Square",10,10)
square.area()
print("==========================")
rhombus = Shape("Rhombus",18,25)
rhombus.area()
print("==========================")
rectangle = Shape("Rectangle",15,30)
rectangle.area()
print("==========================")
trapezium = Shape("Trapezium",15,30)
trapezium.area()
# Out:
# Area: 125.0
# ==========================
# Area: 100
# ==========================
# Area: 225.0
# ==========================
# Area: 450
# ==========================
# Area: Shape unknown

# %%
#Task_6

class Calculator:
    def __init__(self):
        self.a=0
        self.b=0
        self.operator=None
        print("Calculator is ready!")
    def calculate(self,a,b,operator):
        self.a=a
        self.b=b
        self.operator=operator
        if self.operator=="+":
            return self.a+self.b
        elif self.operator=="-":
            return self.a-self.b
        elif self.operator=="*":
            return self.a*self.b
        elif self.operator=="/":
            return self.a/self.b
    def showCalculation(self):
        if self.operator == "+":
            print(f"{self.a}{self.operator}{self.b}={self.a+self.b}")
        elif self.operator == "-":
            print(f"{self.a}{self.operator}{self.b}={self.a-self.b}")
        elif self.operator == "*":
            print(f"{self.a}{self.operator}{self.b}={self.a*self.b}")
        elif self.operator == "/":
            print(f"{self.a}{self.operator}{self.b}={self.a/self.b}")

c1 = Calculator()
print("==================")
val = c1.calculate(10, 20, '+')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 10, '-')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 5, '*')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 16, '/')
print("Returned value:", val)
c1.showCalculation()
# Out:
# Calculator is ready!
# ==================
# Returned value: 30
# 10+20=30
# ==================
# Returned value: 20
# 30-10=20
# ==================
# Returned value: 100
# 20*5=100
# ==================
# Returned value: 6.25
# 100/16=6.25

# %%
#Task_7

class Student:
    def __init__(self,name,id,dept,cg):
        self.name=name
        self.id=id
        self.dept=dept
        self.cgpa=cg
    def calculate_CGPA(self):
        sum=0
        for i in self.cgpa:
            sum+=(i*3)
        final_cg = sum/(len(self.cgpa)*3)
        self.cgpa=final_cg
    def print_details(self):
        print(f"Name: {self.name}, ID: {self.id}")
        print(f"Department: {self.dept}")
        if self.cgpa>3.80:
            print("Your academic standing is 'Highest Distinction'")
        elif self.cgpa>3.65:
            print("Your academic standing is 'High Distinction'")
        elif self.cgpa>3.50:
            print("Your academic standing is 'Distinction'")
        elif self.cgpa>2.00:
            print("Your academic standing is 'Satisfactory'")
        elif self.cgpa<2.00:
            print("Sorry, you cannot graduate")

s1 = Student('Dora', '15995599','CSE', [4,3.7,3.7,4])
s1.calculate_CGPA()
print("==========================")
s1.print_details()
print("==========================")
s2 = Student('Pingu', '12312322', 'EEE', [1.7,1.3,1.3,1.3,1])
s2.calculate_CGPA()
print("==========================")
s2.print_details()
print("==========================")
s3 = Student('Bob', '13311331', 'CSE', [2,3,3,3.7,2.7,2.7])
s3.calculate_CGPA()
print("==========================")
s3.print_details()
# Out:
# ==========================
# Name: Dora, ID: 15995599
# Department: CSE
# Your academic standing is 'Highest Distinction'
# ==========================
# ==========================
# Name: Pingu, ID: 12312322
# Department: EEE
# Sorry, you cannot graduate
# ==========================
# ==========================
# Name: Bob, ID: 13311331
# Department: CSE
# Your academic standing is 'Satisfactory'

# %%
#Task_8

class Shinobi:
    def __init__(self,name,rank):
        self.name=name
        self.rank=rank
        self.salary=0
        self.mission=0
    def calSalary(self,mission):
        self.mission=mission
        if self.rank=="Genin":
            self.salary=self.mission*50
        elif self.rank=="Chunin":
            self.salary=self.mission*100
        else:
            self.salary=self.mission*500
    def printInfo(self):
        print(f"Name: {self.name}")
        print(f"Rank: {self.rank}")
        print(f"Number of mission: {self.mission}")
        print(f"Salary: {self.salary}")
    def changeRank(self,changeto):
        self.rank=changeto

naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 250
# ====================
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ====================
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500

# %%
#Task_9

class Programmer:
    def __init__(self,name,language,exp):
        self.name=name
        self.language=language
        self.exp=exp
        print("Horray! A new programmer is born")
    def printDetails(self):
        print(f"Name: {self.name}")
        print(f"Language: {self.language}")
        print(f"Experience: {self.exp}")
    def addExp(self,addex):
        self.addex=addex
        self.exp+=self.addex

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4
# Name: Jon Snow
# Language: Python
# Experience: 9

# %%
#Task_10

class UberEats:
    def __init__(self,name,num,address):
        self.name=name
        self.num=num
        self.address=address
        print(f"{self.name}, Welcome to UberEats!")
    def add_items(self,item1,item2,price1,price2):
        self.item1=item1
        self.item2=item2
        self.price1=price1
        self.price2=price2
        self.total=self.price1+self.price2
        dict1={}
        self.dict1=dict1
        self.dict1[self.item1]=self.price1
        self.dict1[self.item2]=self.price2
    def print_order_detail(self):
        print(f"User Details: Name: {self.name}")
        print(f"Phone: {self.num}, Address: {self.address}")
        print(f"Total Paid Amount: {self.total}")
        return ""

order1 = UberEats("Shakib", "01719658xxx", "Mohakhali")
print("=========================")
order1.add_items("Burger", "Coca Cola", 220, 50)
print("=========================")
print(order1.print_order_detail())
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara")
print("=========================")
order2.add_items("Pineapple", "Dairy Milk", 80, 70)
print("=========================")
print(order2.print_order_detail())
# Out:
# Shakib, Welcome to UberEats!
# =========================
# =========================
# User Details: Name: Shakib
# Phone: 01719658xxx, Address: Mohakhali
# Total Paid Amount: 270
#
# =========================
# Siam, Welcome to UberEats!
# =========================
# =========================
# User Details: Name: Siam
# Phone: 01719659xxx, Address: Uttara
# Total Paid Amount: 150

# %%
#Task_11

class Spotify:
    def __init__(self,playlist):
        self.playlist=playlist
        print("Welcome to Spotify!")
    def playing_number(self,num):
        if num>len(self.playlist):
            return(f"{num} number song not found. Your playlist has {len(self.playlist)} songs only. \n##########################")
        else:
            return(f"Playing {num} number song for you \nSong name: {self.playlist[num-1]} \n##########################")
    def add_to_playlist(self,song):
        self.playlist.append(song)

user1 = Spotify(["See You Again", "Uptown Funk", "Hello"])
print("=========================")
print(user1.playing_number(4))
user1.add_to_playlist("Dusk Till Dawn")
print(user1.playing_number(3))
print(user1.playing_number(4))
# Out:
# Welcome to Spotify!
# =========================
# 4 number song not found. Your playlist has 3 songs only.
# ##########################
# Playing 3 number song for you
# Song name: Hello
# ##########################
# Playing 4 number song for you
# Song name: Dusk Till Dawn
# ##########################
